# %%
import sys
import os

# research-template 디렉토리의 절대 경로 설정
# 현재 노트북 파일 위치를 기준으로 경로를 맞게 조정해야 할 수 있습니다.
RESEARCH_TEMPLATE_ROOT = os.path.abspath(os.path.join('..', '..')) 

# 파이썬 경로에 research/python 추가
RESEARCH_PYTHON_PATH = os.path.join(RESEARCH_TEMPLATE_ROOT, 'research', 'python')
if RESEARCH_PYTHON_PATH not in sys.path:
    sys.path.append(RESEARCH_PYTHON_PATH)

# %%
# 필요한 모듈 임포트
from settings.training_para import TrainingArgs
from utils.training_utils import load_or_create_dataset, setup_environment
# Out:
# ℹ️ CuPy/CuDF not found. GPU backend is disabled.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 # 필요한 모듈 임포트
#       2 from settings.training_para import TrainingArgs
# ----> 3 from utils.training_utils import load_or_create_dataset, setup_environment
#
# File ~/Documents/QCBM-LSTM/research/python/utils/training_utils.py:30
#      28 from model.lstm.noisy_lstm_v3 import NoisyLSTMv3
#      29 from model.prior.prior_cls import RandomChoiceSampler
# ---> 30 from model.prior.prior_qcbm import SingleBasisQCBM, QCBMAnsatz, ScipyOptimizer
#      33 # =============================================================================
#      34 # Environment and Configuration Utils
#      35 # =============================================================================
#      37 def setup_environment():
#
# ...

# %%
setup_environment()
args = parse_arguments()

# %%
data, selfies, train_compounds = load_or_create_dataset(args)
